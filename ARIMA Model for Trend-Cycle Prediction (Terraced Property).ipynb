# %%
import pandas as pd
from statsmodels.tsa.arima.model import ARIMA

# %%
# Load the decomposed data
df = pd.read_csv('eng_pp_9523_eda_pivoted.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  Year     Month  price Old/New  Detached  Semi-detached  \
# 0           0  1995  February  44500       N         0              0
# 1           1  1995   January  56500       N         0              0
# 2           2  1995      July  58000       N         0              0
# 3           3  1995      June  51000       N         0              1
# 4           4  1995     March  17000       N         0              0
#
#    Terraced  Flat  Others            Street       Locality      Town/City  \
# 0         1     0       0       HOWICK PARK     SUNDERLAND     SUNDERLAND
# 1         1     0       0  BRICK KILN CLOSE     COGGESHALL     COLCHESTER
# 2         1     0       0  RAINSBROOK DRIVE        SHIRLEY       SOLIHULL
# 3         0     0       0        MERRY HILL  BRIERLEY HILL  BRIERLEY HILL
# 4         1     0       0     DENMAN STREET      ROTHERHAM      ROTHERHAM
#
#      District           County
# 0  SUNDERLAND    TYNE AND WEAR
# 1   BRAINTREE            ESSEX
# ...

# %%
df['Date'] = pd.to_datetime(df['Year'].astype(str) + '-' + df['Month'].astype(str))
df.set_index('Date', inplace=True)
df.drop(['Year', 'Month'], axis=1, inplace=True)

# %%
df.head()
# Out:
#             Unnamed: 0  price Old/New  Detached  Semi-detached  Terraced  \
# Date
# 1995-02-01           0  44500       N         0              0         1
# 1995-01-01           1  56500       N         0              0         1
# 1995-07-01           2  58000       N         0              0         1
# 1995-06-01           3  51000       N         0              1         0
# 1995-03-01           4  17000       N         0              0         1
#
#             Flat  Others            Street       Locality      Town/City  \
# Date
# 1995-02-01     0       0       HOWICK PARK     SUNDERLAND     SUNDERLAND
# 1995-01-01     0       0  BRICK KILN CLOSE     COGGESHALL     COLCHESTER
# 1995-07-01     0       0  RAINSBROOK DRIVE        SHIRLEY       SOLIHULL
# 1995-06-01     0       0        MERRY HILL  BRIERLEY HILL  BRIERLEY HILL
# 1995-03-01     0       0     DENMAN STREET      ROTHERHAM      ROTHERHAM
#
#               District           County
# Date
# ...

# %%
df_terraced = df[['Terraced']]

# %%
df_terraced.head()
# Out:
#             Terraced
# Date
# 1995-02-01         1
# 1995-01-01         1
# 1995-07-01         1
# 1995-06-01         0
# 1995-03-01         1

# %%
#Change data type from float64 to float8 to optimise memory demand
#df = df.astype(float)
#df = df.astype({'Trend': 'float32', 'Seasonal': 'float32',  'Residual': 'float32'})

# %%
#df.dtypes

# %%
#Convert Date to DateTime
#df_terraced['Date'] = pd.to_datetime(df['Date'])

# %%
# Select trend component
trend = df_terraced["Terraced"]

# %%
# Identify best ARIMA parameters using tools like AIC or BIC
# (This code snippet omits parameter identification)

# %%
# Define and fit the ARIMA model
#model = ARIMA(trend, order=(3, 0, 0))  # Replace (p, d, q) with identified parameters
#model_fit = model.fit()

# %%
# Predict future values (specify desired number of predictions)
#future_predictions = model_fit.forecast(steps=13)

# %%
# Print the predicted trend values
#print(f"Predicted future trend values: {future_predictions}")
