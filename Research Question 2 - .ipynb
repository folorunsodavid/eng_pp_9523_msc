# %%
Historical trends in property type transactions in England from 1995 to 2023:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
# Load the dataset
df = pd.read_csv('eng_pp_9523_eda.csv')

# %%
# Data Preprocessing
# Convert non-numeric values in Property_Type to numerical values
property_type_mapping = {'T': 1, 'S': 2, 'D': 3, 'F': 4, 'O': 5}
df['Property_Type'] = df['Property_Type'].map(property_type_mapping)

# %%
# Research Question 2: Demand for specific property types over time
property_types = ['Terraced','Detached', 'Semi-detached', 'Flat', 'Other']
plt.figure(figsize=(12, 6))
for prop_type in property_types:
    prop_type_code = property_type_mapping[prop_type[0].upper()]
    prop_type_data = df[df['Property_Type'] == prop_type_code]
    sns.lineplot(x='Year', y='price', data=prop_type_data, label=prop_type)

plt.title('Demand for Specific Property Types (1995-2023)')
plt.xlabel('Year')
plt.ylabel('Average Price')
plt.legend()
plt.show()

# %%
# Research Question 2: Demand for specific property types over time
property_types = ['Terraced','Detached', 'Semi-detached', 'Flat', 'Other']
plt.figure(figsize=(12, 6))
for prop_type in property_types:
    prop_type_code = property_type_mapping[prop_type[0].upper()]
    prop_type_data = df[df['Property_Type'] == prop_type_code]
    sns.lineplot(x='Year', y= df['Property_Type'], data=prop_type_data, label=prop_type)

plt.title('Demand for Specific Property Types (1995-2023)')
plt.xlabel('Year')
plt.ylabel('Average Price')
plt.legend()
plt.show()
