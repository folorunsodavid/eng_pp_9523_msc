# %%
import pandas as pd
from statsmodels.tsa.stattools import adfuller
import matplotlib.pyplot as plt

# %%
# Load the dataset
data = pd.read_csv('ts_detached.csv', index_col='Date', parse_dates=True)  # Assuming a date column

# %%
data
# Out:
#             Detached
# Date
# 1995-01-31      9473
# 1995-02-28      9667
# 1995-03-31     13431
# 1995-04-30     11929
# 1995-05-31     13169
# ...              ...
# 2023-07-31      8053
# 2023-08-31      8893
# 2023-09-30      6916
# 2023-10-31      3206
# 2023-11-30      1546
#
# [347 rows x 1 columns]

# %%
# Visualize the time series
data.plot(figsize=(12, 6))
plt.title('Time Series Plot')
plt.show()

# %%
# Perform Augmented Dickey-Fuller (ADF) test
adf_result = adfuller(data)
print('ADF Statistic:', adf_result[0])
print('p-value:', adf_result[1])
# Out:
# ADF Statistic: -1.6812322570235374
# p-value: 0.44080719737982893

# %%
# Interpret the results
if adf_result[1] < 0.05:
    print('Time series is likely stationary.')
else:
    print('Time series is likely non-stationary. Consider differencing or transformations.')
# Out:
# Time series is likely non-stationary. Consider differencing or transformations.
