# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('eng_pp_9523_drop_unused_columns.csv')

# %%
df
# Out:
#          Date_of_Transfer Property_Type   price Old/New            Street  \
# 0              1995-02-03             T   44500       N       HOWICK PARK
# 1              1995-01-13             T   56500       N  BRICK KILN CLOSE
# 2              1995-07-28             T   58000       N  RAINSBROOK DRIVE
# 3              1995-06-28             S   51000       N        MERRY HILL
# 4              1995-03-10             T   17000       N     DENMAN STREET
# ...                   ...           ...     ...     ...               ...
# 22653981       2023-01-12             S  158000       N  LONGFELLOW DRIVE
# 22653982       2023-05-15             S  172000       N   EARLSWOOD DRIVE
# 22653983       2023-04-21             D  272000       N  CASTLETON AVENUE
# 22653984       2023-06-09             D  260000       N      COOPER CLOSE
# 22653985       2023-05-19             S  175000       N   MOORLAND AVENUE
#
#                  Locality      Town/City    District           County
# 0              SUNDERLAND     SUNDERLAND  SUNDERLAND    TYNE AND WEAR
# 1              COGGESHALL     COLCHESTER   BRAINTREE            ESSEX
# 2                 SHIRLEY       SOLIHULL    SOLIHULL    WEST MIDLANDS
# 3           BRIERLEY HILL  BRIERLEY HILL      DUDLEY    WEST MIDLANDS
# 4               ROTHERHAM      ROTHERHAM   ROTHERHAM  SOUTH YORKSHIRE
# ...                   ...            ...         ...              ...
# 22653981              NaN        WORKSOP   BASSETLAW  NOTTINGHAMSHIRE
# 22653982              NaN      MANSFIELD   MANSFIELD  NOTTINGHAMSHIRE
# 22653983           ARNOLD     NOTTINGHAM     GEDLING  NOTTINGHAMSHIRE
# 22653984  CROPWELL BISHOP     NOTTINGHAM  RUSHCLIFFE  NOTTINGHAMSHIRE
# 22653985     WALKERINGHAM      DONCASTER   BASSETLAW  NOTTINGHAMSHIRE
#
# [22653986 rows x 9 columns]

# %%
df
# Out:
#          Date_of_Transfer Property_Type   price Old/New            Street  \
# 0              1995-02-03             T   44500       N       HOWICK PARK
# 1              1995-01-13             T   56500       N  BRICK KILN CLOSE
# 2              1995-07-28             T   58000       N  RAINSBROOK DRIVE
# 3              1995-06-28             S   51000       N        MERRY HILL
# 4              1995-03-10             T   17000       N     DENMAN STREET
# ...                   ...           ...     ...     ...               ...
# 22653981       2023-01-12             S  158000       N  LONGFELLOW DRIVE
# 22653982       2023-05-15             S  172000       N   EARLSWOOD DRIVE
# 22653983       2023-04-21             D  272000       N  CASTLETON AVENUE
# 22653984       2023-06-09             D  260000       N      COOPER CLOSE
# 22653985       2023-05-19             S  175000       N   MOORLAND AVENUE
#
#                  Locality      Town/City    District           County
# 0              SUNDERLAND     SUNDERLAND  SUNDERLAND    TYNE AND WEAR
# 1              COGGESHALL     COLCHESTER   BRAINTREE            ESSEX
# 2                 SHIRLEY       SOLIHULL    SOLIHULL    WEST MIDLANDS
# 3           BRIERLEY HILL  BRIERLEY HILL      DUDLEY    WEST MIDLANDS
# 4               ROTHERHAM      ROTHERHAM   ROTHERHAM  SOUTH YORKSHIRE
# ...                   ...            ...         ...              ...
# 22653981              NaN        WORKSOP   BASSETLAW  NOTTINGHAMSHIRE
# 22653982              NaN      MANSFIELD   MANSFIELD  NOTTINGHAMSHIRE
# 22653983           ARNOLD     NOTTINGHAM     GEDLING  NOTTINGHAMSHIRE
# 22653984  CROPWELL BISHOP     NOTTINGHAM  RUSHCLIFFE  NOTTINGHAMSHIRE
# 22653985     WALKERINGHAM      DONCASTER   BASSETLAW  NOTTINGHAMSHIRE
#
# [22653986 rows x 9 columns]

# %%
# Display unique property types
unique_prop_types = df['Property_Type'].unique()
print("Unique Property Types:")
for prop_type in unique_prop_types:
    print(prop_type)
# Out:
# Unique Property Types:
# T
# S
# D
# F
# O

# %%
# Convert the date column to datetime
df['Date_of_Transfer'] = pd.to_datetime(df['Date_of_Transfer'])

# %%
# Extract year and month as separate columns
df['Year'] = df['Date_of_Transfer'].dt.year
df['Month'] = df['Date_of_Transfer'].dt.month_name()

# %%
df.set_index('Date_of_Transfer', inplace = True)

# %%
df
# Out:
#                  Property_Type   price Old/New            Street  \
# Date_of_Transfer
# 1995-02-03                   T   44500       N       HOWICK PARK
# 1995-01-13                   T   56500       N  BRICK KILN CLOSE
# 1995-07-28                   T   58000       N  RAINSBROOK DRIVE
# 1995-06-28                   S   51000       N        MERRY HILL
# 1995-03-10                   T   17000       N     DENMAN STREET
# ...                        ...     ...     ...               ...
# 2023-01-12                   S  158000       N  LONGFELLOW DRIVE
# 2023-05-15                   S  172000       N   EARLSWOOD DRIVE
# 2023-04-21                   D  272000       N  CASTLETON AVENUE
# 2023-06-09                   D  260000       N      COOPER CLOSE
# 2023-05-19                   S  175000       N   MOORLAND AVENUE
#
#                          Locality      Town/City    District           County  \
# Date_of_Transfer
# 1995-02-03             SUNDERLAND     SUNDERLAND  SUNDERLAND    TYNE AND WEAR
# 1995-01-13             COGGESHALL     COLCHESTER   BRAINTREE            ESSEX
# 1995-07-28                SHIRLEY       SOLIHULL    SOLIHULL    WEST MIDLANDS
# 1995-06-28          BRIERLEY HILL  BRIERLEY HILL      DUDLEY    WEST MIDLANDS
# 1995-03-10              ROTHERHAM      ROTHERHAM   ROTHERHAM  SOUTH YORKSHIRE
# ...                           ...            ...         ...              ...
# 2023-01-12                    NaN        WORKSOP   BASSETLAW  NOTTINGHAMSHIRE
# 2023-05-15                    NaN      MANSFIELD   MANSFIELD  NOTTINGHAMSHIRE
# 2023-04-21                 ARNOLD     NOTTINGHAM     GEDLING  NOTTINGHAMSHIRE
# 2023-06-09        CROPWELL BISHOP     NOTTINGHAM  RUSHCLIFFE  NOTTINGHAMSHIRE
# 2023-05-19           WALKERINGHAM      DONCASTER   BASSETLAW  NOTTINGHAMSHIRE
#
#                   Year     Month
# Date_of_Transfer
# 1995-02-03        1995  February
# 1995-01-13        1995   January
# 1995-07-28        1995      July
# 1995-06-28        1995      June
# 1995-03-10        1995     March
# ...                ...       ...
# 2023-01-12        2023   January
# 2023-05-15        2023       May
# 2023-04-21        2023     April
# 2023-06-09        2023      June
# 2023-05-19        2023       May
#
# [22653986 rows x 10 columns]

# %% [markdown]
# <h2>VISUALISATION</h2>

# %%
# Create a count plot
plt.figure(figsize=(12, 6))
plot = sns.countplot(x='Year', hue='Property_Type', data=df)

# Add labels and title
plt.title('Property Types Count by Year')
plt.xlabel('Year')
plt.ylabel('Count')

# Display the legend
plt.legend(title='Property Type')

# Show the plot
plt.show()

# %%
# Group the data by year and property type and calculate the count
grouped_data = df.groupby(['Year', 'Property_Type']).size().reset_index(name='Count')

# Set the style of seaborn
sns.set(style="darkgrid")

# Create a line plot
plt.figure(figsize=(12, 6))
plot = sns.lineplot(x='Year', y='Count', hue='Property_Type', data=grouped_data, marker='o')

# Add labels and title
plt.title('Property Types Count by Year')
plt.xlabel('Year')
plt.ylabel('Count')

# Display the legend
plt.legend(title='Property Type')

# Show the plot
plt.show()
