# %%
import pandas as pd
#import pgeocode
#from geopy.geocoders import Nominatim
#import geopandas as gpd

# %%
df = pd.read_csv("eng_pp_9523.csv")

# %%
# Specify the columns to drop
columns_to_drop = ['postcode', 'Transaction_unique_identifier','Duration', 'PAON', 'SAON', 'PPDCategory_Type', 'Record_Status - monthly_file_only']

# %%
# Drop the specified columns
englandhousing_column_dropped = df.drop(columns=columns_to_drop)

# %%
#englandhousing_column_dropped.to_csv("englandhousing.csv")

# %%
#df = pd.read_csv("englandhousing.csv")

# %%
df2 = pd.DataFrame(englandhousing_column_dropped)

# %%
df2
# Out:
#            price  Date_of_Transfer Property_Type Old/New            Street  \
# 0          44500  1995-02-03 00:00             T       N       HOWICK PARK
# 1          56500  1995-01-13 00:00             T       N  BRICK KILN CLOSE
# 2          58000  1995-07-28 00:00             T       N  RAINSBROOK DRIVE
# 3          51000  1995-06-28 00:00             S       N        MERRY HILL
# 4          17000  1995-03-10 00:00             T       N     DENMAN STREET
# ...          ...               ...           ...     ...               ...
# 22653981  158000  2023-01-12 00:00             S       N  LONGFELLOW DRIVE
# 22653982  172000  2023-05-15 00:00             S       N   EARLSWOOD DRIVE
# 22653983  272000  2023-04-21 00:00             D       N  CASTLETON AVENUE
# 22653984  260000  2023-06-09 00:00             D       N      COOPER CLOSE
# 22653985  175000  2023-05-19 00:00             S       N   MOORLAND AVENUE
#
# ...

# %%
#Data cleaning - dropping null values
df2_cleaned = df2.dropna()

# %%
# Convert the date column to datetime
df2['Date_of_Transfer'] = pd.to_datetime(df2['Date_of_Transfer'])

# %%
# Extract year and month as separate columns
df2['Year'] = df2['Date_of_Transfer'].dt.year
df2['Month'] = df2['Date_of_Transfer'].dt.month_name()

# %%
# Drop the original date column if needed
df2.drop('Date_of_Transfer', axis=1, inplace=True)

# %%
# Print the resulting DataFrame
df2
# Out:
#            price Property_Type Old/New            Street         Locality  \
# 0          44500             T       N       HOWICK PARK       SUNDERLAND
# 1          56500             T       N  BRICK KILN CLOSE       COGGESHALL
# 2          58000             T       N  RAINSBROOK DRIVE          SHIRLEY
# 3          51000             S       N        MERRY HILL    BRIERLEY HILL
# 4          17000             T       N     DENMAN STREET        ROTHERHAM
# ...          ...           ...     ...               ...              ...
# 22653981  158000             S       N  LONGFELLOW DRIVE              NaN
# 22653982  172000             S       N   EARLSWOOD DRIVE              NaN
# 22653983  272000             D       N  CASTLETON AVENUE           ARNOLD
# 22653984  260000             D       N      COOPER CLOSE  CROPWELL BISHOP
# 22653985  175000             S       N   MOORLAND AVENUE     WALKERINGHAM
#
#               Town/City    District           County  Year     Month
# ...

# %%
# Specify desired column order (adjust as needed)
df2_reordered = ['Year', 'Month', 'Property_Type', 'price', 'Old/New', 'Street', 'Locality', 'Town/City', 'District', 'County']

# %%
# Rearrange columns
df2 = df2[df2_reordered]

# %%
df2
# Out:
#           Year     Month Property_Type   price Old/New            Street  \
# 0         1995  February             T   44500       N       HOWICK PARK
# 1         1995   January             T   56500       N  BRICK KILN CLOSE
# 2         1995      July             T   58000       N  RAINSBROOK DRIVE
# 3         1995      June             S   51000       N        MERRY HILL
# 4         1995     March             T   17000       N     DENMAN STREET
# ...        ...       ...           ...     ...     ...               ...
# 22653981  2023   January             S  158000       N  LONGFELLOW DRIVE
# 22653982  2023       May             S  172000       N   EARLSWOOD DRIVE
# 22653983  2023     April             D  272000       N  CASTLETON AVENUE
# 22653984  2023      June             D  260000       N      COOPER CLOSE
# 22653985  2023       May             S  175000       N   MOORLAND AVENUE
#
#                  Locality      Town/City    District           County
# ...

# %%
# Save the modified dataset
df2.to_csv("eng_pp_9523_eda.csv", index=False)
